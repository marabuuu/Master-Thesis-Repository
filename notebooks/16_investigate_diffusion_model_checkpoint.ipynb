# %% [markdown]
# # Investigate diffusion model checkpoint

# %%
from mopadi.configs.templates import tcga_brca_autoenc
from mopadi.utils.encode import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mopadi.configs.templates import tcga_brca_autoenc
#       2 from mopadi.utils.encode import *
#
# ModuleNotFoundError: No module named 'mopadi.configs'

# %%
diffusion_encoder = ImageEncoder(
        tcga_brca_autoenc(), 
        autoenc_path="split_ckpts/diffusion_without_encoder.ckpt", 
        feat_extractor = None,
        device="cuda:0"
)
